# %% [markdown]
# # Data1(Demo) 분석

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# set needed variables
plt.rcParams['font.family'] = 'Malgun Gothic' # font
age_order = ['20대', '30대', '40대', '50대', '60대', '70대']
zone_order = ['Z01', 'Z02', 'Z03', 'Z04', 'Z05', 'Z06', 'Z07', 'Z08', 
    'Z09', 'Z10', 'Z11', 'Z12', 'Z13', 'Z14', 'Z15', 'Z16', 'Z17']
gen_order = ['남성', '여성']

# %%
# read data
data1 = pd.read_csv("../Data/privateData/LPOINT_BIG_COMP_01_DEMO.csv", low_memory=False)
data1.head()
# Out:
#          cust ma_fem_dv ages zon_hlv
# 0  M000034966        여성  40대     Z07
# 1  M000059535        여성  30대     Z12
# 2  M000136117        여성  30대     Z11
# 3  M000201112        여성  50대     Z17
# 4  M000225114        여성  40대     Z17

# %%
# 남성/여성 비교
sns.countplot(data=data1, x='ma_fem_dv', order=gen_order).set_title("성별에 따른 고객의 수")
plt.show()

# %% [markdown]
# * 여성 고객이 남성 고객보다 많다

# %%
# 연령대 비교
sns.countplot(data=data1, x='ages', order=age_order).set_title("연령에 따른 고객의 수")
plt.show()

# %% [markdown]
# * 3,40대가 주력 고객층이다

# %%
# 거주지역 비교
sns.countplot(data=data1, x='zon_hlv', order=zone_order).set_title("거주지역에 따른 고객의 수")
plt.show()

# %% [markdown]
# * Z10, Z17이 핵심 지역이다

# %%
# 연령&성별 비교
sns.countplot(data=data1, x='ages', hue='ma_fem_dv', order=age_order, hue_order=gen_order).set_title("성별과 연령에 따른 고객의 수")
plt.show()

# %% [markdown]
# * 3,40대 여성이 주요 고객층이다

# %%
# 연령&거주지역 비교
sns.countplot(data=data1, x='zon_hlv', hue='ages', order=zone_order, hue_order=age_order)
plt.show()

# %% [markdown]
# * 연령과 거주지역을 묶어서 나오는 유의미한 데이터는 없다

# %%
# 성별&거주지역 비교
sns.countplot(data=data1, x='zon_hlv', hue='ma_fem_dv', order=zone_order, hue_order=gen_order)
plt.show()

# %% [markdown]
# * 성별과 거주지역을 묶어서 나오는 유의미한 데이터는 없다

# %% [markdown]
# ---
# # Data1(Demo) 분석 결과
# * 3,40대 여성이 주요 고객층이다
# * Z10, Z17이 핵심 지역이다
